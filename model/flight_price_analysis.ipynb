# %% [markdown]
# # Flight Ticket Price Prediction
#
# This notebook contains exploratory data analysis and visualizations.
# Use the provided Python scripts for preprocessing, training, and evaluation.
